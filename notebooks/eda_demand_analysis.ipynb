# %%
# EDA Plan: Food Delivery Demand Analysis

# 1. Load and inspect the cleaned order dataset for missing values and outliers
# 2. Analyze order volume distribution across different restaurant zones
# 3. Visualize hourly order trends to identify the 7-9 PM peak window
# 4. Compare weekday vs weekend demand patterns across zones
# 5. Identify the top zones consistently showing peak demand for model targeting
